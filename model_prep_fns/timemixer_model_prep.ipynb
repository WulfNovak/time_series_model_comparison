# %%
import time
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import pickle
import os
from neuralforecast.core import NeuralForecast
from neuralforecast.losses.pytorch import MAE, MSE
from neuralforecast.models import TimeMixer
os.chdir('C:/Users/WulfN/Python Projects/time_series_model_comparison')

# Multiple Outputs per cell
# %config interactive_shell.ast_node_interactivity='all'

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Read Data
with open('datasets/energy_dt.pickle', 'rb') as data: 
    energy_dt = pickle.load(data)

# Test train split
x_energy = energy_dt.drop(columns = ['total_Wh', 'rv1', 'rv2'])
x_energy_sc = MinMaxScaler().fit_transform(x_energy)
y_energy = energy_dt['total_Wh']

# May need to make this a TimeSeriesDataset via nixtla 

# x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_energy_sc, y_energy, test_size = .2, shuffle = False)

# %%
horizon = len(y_test_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 horizon = len(y_test_1)
# ----> 3 test_df = Y_df.groupby('unique_id').tail(horizon)
#       4 train_df = Y_df.drop(test_df.index).reset_index(drop=True)
#
# NameError: name 'Y_df' is not defined

# %%
# TimeMixer Algorithm

# h (horizon), input_size, n_series, early_stop_patience, scaler_type
# learning_rate, dropout rate, e_layers (encoder layers), step_size, random_seed

horizon = len(y_train_1)

ts_model = TimeMixer( # what is causing this to require so much memory? 
    input_size=len(y_train_1) * x_train_1.shape[1], # ~15800 * 26 = ~410800
        # If window size, then try values like 144 (day), 1008 (week), 4320 (month)
    h=horizon, # horizon, 15788 of 10 minute steps
    n_series=x_train_1.shape[1],
    early_stop_patience_steps=3,
    max_steps=100,
    learning_rate=.001, # future hyperparam
    loss=MAE(),
    #valid_loss=MAE(),
    batch_size = 16 # consider removal
    )

# ts_train = NeuralForecast(models=[ts_model], 
#                           freq='M' # What to place for the frequency? freq='M'
#                            )

# ts_train.fit(df=Y_train_df, 
#              #static_df =
#              val_size=horizon
#              )
                           

# Optimal params as reported by paper
#  timemixer_model = TimeMixer(input_size=horizon, 
#                                 h=horizon, 
#                                 n_series=7,
#                                 e_layers=2,
#                                 d_model=16,
#                                 d_ff=32,
#                                 down_sampling_layers=3,
#                                 down_sampling_window=2,
#                                 learning_rate=0.01,
#                                 scaler_type='robust',
#                                 batch_size=16, 
#                                 early_stop_patience_steps=5)

# What is this training on ? 

#ts_model.fit(x_train_1, targets = y_train_1)
# Out:
# Seed set to 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 8
#       1 # TimeMixer Algorithm
#       2
#       3 # h (horizon), input_size, n_series, early_stop_patience, scaler_type
#       4 # learning_rate, dropout rate, e_layers (encoder layers), step_size, random_seed
#       6 horizon = len(y_train_1)
# ----> 8 ts_model = TimeMixer( # what is causing this to require so much memory?
#       9     input_size=len(y_train_1) * x_train_1.shape[1], # ~15800 * 26 = ~410800
#      10         # If window size, then try values like 144 (day), 1008 (week), 4320 (month)
#      11     h=horizon, # horizon, 15788 of 10 minute steps
#      12     n_series=x_train_1.shape[1],
#      13     early_stop_patience_steps=3,
#      14     max_steps=100,
#      15     learning_rate=.001, # future hyperparam
#      16     loss=MAE(),
#      17     #valid_loss=MAE(),
# ...

# %%
# Out:
# 410800

# %%
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

windowed_train = timeseries_dataset_from_array(
    data=x_train_1, 
    targets=y_train_1,
    sequence_length=6) # 6, 24, 72, 144

ts_model.TimeMixer.fit(x_train_1, 
                       #val_size=0, 
                       #test_size=0, 
                       random_seed=42,
                       distributed_config=None)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.preprocessing import timeseries_dataset_from_array
#       3 windowed_train = timeseries_dataset_from_array(
#       4     data=x_train_1,
#       5     targets=y_train_1,
#       6     sequence_length=6) # 6, 24, 72, 144
#       8 temporal_cols = list(x_energy.columns)
#
# File c:\Users\WulfN\Python Projects\learn_ts\ts_env_310\lib\site-packages\tensorflow\__init__.py:47
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File c:\Users\WulfN\Python Projects\learn_ts\ts_env_310\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
# ...
